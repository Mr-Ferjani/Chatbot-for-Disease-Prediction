# %%
import numpy as np
import pandas as pd 
import json
import nltk
from nltk import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords #used to extract repetitve words with less unimportant meaning
import re #used to regularize - meaning removing punctuations
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
#from sklearn.feature_extraction.text import CountVectorizer
#from sklearn.feature_extraction.text import TfidfVectorizer
import random
import pickle
from tqdm.notebook import trange # https://tqdm.github.io/

# %% [markdown]
# Reading the dataset

# %%
with open('intents.json','r') as infile:
    intents=json.load(infile)

# %%
intents
# Out:
# {'intents': [{'tag': 'Gastroenteritis',
#    'patterns': [' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     'sunken_eyes  dehydration diarrhoea',
#     'diarrhoea  vomiting dehydration',
#     'sunken_eyes  vomiting diarrhoea',
#     'sunken_eyes  vomiting dehydration',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     'sunken_eyes  dehydration diarrhoea',
#     'diarrhoea  vomiting dehydration',
#     'sunken_eyes  vomiting diarrhoea',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     'sunken_eyes  dehydration diarrhoea',
#     'diarrhoea  vomiting dehydration',
#     'sunken_eyes  vomiting diarrhoea',
#     'sunken_eyes  vomiting dehydration',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     'sunken_eyes  dehydration diarrhoea',
#     'diarrhoea  vomiting dehydration',
#     'sunken_eyes  vomiting diarrhoea',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     'sunken_eyes  dehydration diarrhoea',
#     'diarrhoea  vomiting dehydration',
#     'sunken_eyes  vomiting diarrhoea',
#     'sunken_eyes  vomiting dehydration',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     'sunken_eyes  dehydration diarrhoea',
#     'diarrhoea  vomiting dehydration',
#     'sunken_eyes  vomiting diarrhoea',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     'sunken_eyes  dehydration diarrhoea',
#     'diarrhoea  vomiting dehydration',
#     'sunken_eyes  vomiting diarrhoea',
#     'sunken_eyes  vomiting dehydration',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     'sunken_eyes  dehydration diarrhoea',
#     'diarrhoea  vomiting dehydration',
#     'sunken_eyes  vomiting diarrhoea',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     'sunken_eyes  dehydration diarrhoea',
#     'diarrhoea  vomiting dehydration',
#     'sunken_eyes  vomiting diarrhoea',
#     'sunken_eyes  vomiting dehydration',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     'sunken_eyes  dehydration diarrhoea',
#     'diarrhoea  vomiting dehydration',
#     'sunken_eyes  vomiting diarrhoea',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     'sunken_eyes  dehydration diarrhoea',
#     'diarrhoea  vomiting dehydration',
#     'sunken_eyes  vomiting diarrhoea',
#     'sunken_eyes  vomiting dehydration',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     'sunken_eyes  dehydration diarrhoea',
#     'diarrhoea  vomiting dehydration',
#     'sunken_eyes  vomiting diarrhoea',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes',
#     ' vomiting dehydration diarrhoea sunken_eyes'],
#    'responses': ['you have Gastroenteritis']},
#   {'tag': 'Peptic ulcer diseae',
#    'patterns': [' vomiting internal_itching passage_of_gases loss_of_appetite abdominal_pain',
#     ' vomiting internal_itching passage_of_gases indigestion abdominal_pain',
#     ' internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite abdominal_pain',
#     ' vomiting internal_itching passage_of_gases indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion',
#     ' vomiting internal_itching loss_of_appetite indigestion abdominal_pain',
#     ' vomiting passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite abdominal_pain',
#     ' vomiting internal_itching passage_of_gases indigestion abdominal_pain',
#     ' internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite abdominal_pain',
#     ' vomiting internal_itching passage_of_gases indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion',
#     ' vomiting internal_itching loss_of_appetite indigestion abdominal_pain',
#     ' vomiting passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite abdominal_pain',
#     ' vomiting internal_itching passage_of_gases indigestion abdominal_pain',
#     ' internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite abdominal_pain',
#     ' vomiting internal_itching passage_of_gases indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion',
#     ' vomiting internal_itching loss_of_appetite indigestion abdominal_pain',
#     ' vomiting passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite abdominal_pain',
#     ' vomiting internal_itching passage_of_gases indigestion abdominal_pain',
#     ' internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite abdominal_pain',
#     ' vomiting internal_itching passage_of_gases indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion',
#     ' vomiting internal_itching loss_of_appetite indigestion abdominal_pain',
#     ' vomiting passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite abdominal_pain',
#     ' vomiting internal_itching passage_of_gases indigestion abdominal_pain',
#     ' internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite abdominal_pain',
#     ' vomiting internal_itching passage_of_gases indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion',
#     ' vomiting internal_itching loss_of_appetite indigestion abdominal_pain',
#     ' vomiting passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite abdominal_pain',
#     ' vomiting internal_itching passage_of_gases indigestion abdominal_pain',
#     ' internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite abdominal_pain',
#     ' vomiting internal_itching passage_of_gases indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion',
#     ' vomiting internal_itching loss_of_appetite indigestion abdominal_pain',
#     ' vomiting passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain',
#     ' vomiting internal_itching passage_of_gases loss_of_appetite indigestion abdominal_pain'],
#    'responses': ['you have Peptic ulcer diseae']},
#   {'tag': 'AIDS',
#    'patterns': [' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever extra_marital_contacts',
#     ' muscle_wasting extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever patches_in_throat',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever extra_marital_contacts',
#     ' muscle_wasting high_fever patches_in_throat',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever extra_marital_contacts',
#     ' muscle_wasting extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever patches_in_throat',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever extra_marital_contacts',
#     ' muscle_wasting high_fever patches_in_throat',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever extra_marital_contacts',
#     ' muscle_wasting extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever patches_in_throat',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever extra_marital_contacts',
#     ' muscle_wasting high_fever patches_in_throat',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever extra_marital_contacts',
#     ' muscle_wasting extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever patches_in_throat',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever extra_marital_contacts',
#     ' muscle_wasting high_fever patches_in_throat',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever extra_marital_contacts',
#     ' muscle_wasting extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever patches_in_throat',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever extra_marital_contacts',
#     ' muscle_wasting high_fever patches_in_throat',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever extra_marital_contacts',
#     ' muscle_wasting extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever patches_in_throat',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever extra_marital_contacts patches_in_throat',
#     ' muscle_wasting high_fever extra_marital_contacts',
#     ' muscle_wasting high_fever patches_in_throat',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts',
#     ' high_fever patches_in_throat muscle_wasting extra_marital_contacts'],
#    'responses': ['you have AIDS']},
#   {'tag': 'Hypertension',
#    'patterns': [' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration',
#     ' dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration',
#     ' dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration',
#     ' dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration',
#     ' dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration',
#     ' dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration',
#     ' dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration',
#     ' dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration',
#     ' dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration',
#     ' dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration',
#     ' dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration',
#     ' dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration',
#     ' dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache',
#     ' chest_pain dizziness loss_of_balance lack_of_concentration headache'],
#    'responses': ['you have Hypertension']},
#   {'tag': 'Drug Reaction',
#    'patterns': ['skin_rash  stomach_pain burning_micturition itching',
#     ' stomach_pain burning_micturition itching',
#     'skin_rash burning_micturition  itching',
#     'skin_rash stomach_pain  itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash stomach_pain burning_micturition ',
#     ' stomach_pain burning_micturition itching',
#     'skin_rash burning_micturition  itching',
#     'skin_rash stomach_pain  itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     ' stomach_pain burning_micturition itching',
#     'skin_rash burning_micturition  itching',
#     'skin_rash stomach_pain  itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash stomach_pain burning_micturition ',
#     ' stomach_pain burning_micturition itching',
#     'skin_rash burning_micturition  itching',
#     'skin_rash stomach_pain  itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     ' stomach_pain burning_micturition itching',
#     'skin_rash burning_micturition  itching',
#     'skin_rash stomach_pain  itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash stomach_pain burning_micturition ',
#     ' stomach_pain burning_micturition itching',
#     'skin_rash burning_micturition  itching',
#     'skin_rash stomach_pain  itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     ' stomach_pain burning_micturition itching',
#     'skin_rash burning_micturition  itching',
#     'skin_rash stomach_pain  itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash stomach_pain burning_micturition ',
#     ' stomach_pain burning_micturition itching',
#     'skin_rash burning_micturition  itching',
#     'skin_rash stomach_pain  itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     ' stomach_pain burning_micturition itching',
#     'skin_rash burning_micturition  itching',
#     'skin_rash stomach_pain  itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash stomach_pain burning_micturition ',
#     ' stomach_pain burning_micturition itching',
#     'skin_rash burning_micturition  itching',
#     'skin_rash stomach_pain  itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     ' stomach_pain burning_micturition itching',
#     'skin_rash burning_micturition  itching',
#     'skin_rash stomach_pain  itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash stomach_pain burning_micturition ',
#     ' stomach_pain burning_micturition itching',
#     'skin_rash burning_micturition  itching',
#     'skin_rash stomach_pain  itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching',
#     'skin_rash  stomach_pain burning_micturition itching'],
#    'responses': ['you have Drug Reaction']},
#   {'tag': 'Psoriasis',
#    'patterns': ['skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails',
#     'skin_rash  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails',
#     'skin_rash  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails',
#     'skin_rash  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails',
#     'skin_rash  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails',
#     'skin_rash  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails',
#     'skin_rash  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
#     'skin_rash silver_like_dusting  joint_pain inflammatory_nails small_dents_in_nails skin_peeling',
# ...
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes family_history',
#     ' nausea yellowish_skin fatigue loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes family_history',
#     ' nausea yellowish_skin fatigue loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes family_history',
#     ' nausea yellowish_skin fatigue loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history',
#     ' nausea yellowish_skin fatigue yellowing_of_eyes loss_of_appetite family_history'],
#    'responses': ['you have Hepatitis C']},
#   {'tag': 'GERD',
#    'patterns': [' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue stomach_pain',
#     ' vomiting chest_pain cough acidity stomach_pain',
#     ' chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain ulcers_on_tongue acidity stomach_pain',
#     ' vomiting cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity',
#     ' vomiting chest_pain cough ulcers_on_tongue stomach_pain',
#     ' vomiting chest_pain cough acidity stomach_pain',
#     ' chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue stomach_pain',
#     ' vomiting chest_pain cough acidity stomach_pain',
#     ' chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain ulcers_on_tongue acidity stomach_pain',
#     ' vomiting cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity',
#     ' vomiting chest_pain cough ulcers_on_tongue stomach_pain',
#     ' vomiting chest_pain cough acidity stomach_pain',
#     ' chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue stomach_pain',
#     ' vomiting chest_pain cough acidity stomach_pain',
#     ' chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain ulcers_on_tongue acidity stomach_pain',
#     ' vomiting cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity',
#     ' vomiting chest_pain cough ulcers_on_tongue stomach_pain',
#     ' vomiting chest_pain cough acidity stomach_pain',
#     ' chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue stomach_pain',
#     ' vomiting chest_pain cough acidity stomach_pain',
#     ' chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain ulcers_on_tongue acidity stomach_pain',
#     ' vomiting cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity',
#     ' vomiting chest_pain cough ulcers_on_tongue stomach_pain',
#     ' vomiting chest_pain cough acidity stomach_pain',
#     ' chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue stomach_pain',
#     ' vomiting chest_pain cough acidity stomach_pain',
#     ' chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain ulcers_on_tongue acidity stomach_pain',
#     ' vomiting cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity',
#     ' vomiting chest_pain cough ulcers_on_tongue stomach_pain',
#     ' vomiting chest_pain cough acidity stomach_pain',
#     ' chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue stomach_pain',
#     ' vomiting chest_pain cough acidity stomach_pain',
#     ' chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain ulcers_on_tongue acidity stomach_pain',
#     ' vomiting cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity',
#     ' vomiting chest_pain cough ulcers_on_tongue stomach_pain',
#     ' vomiting chest_pain cough acidity stomach_pain',
#     ' chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain',
#     ' vomiting chest_pain cough ulcers_on_tongue acidity stomach_pain'],
#    'responses': ['you have GERD']}]}

# %% [markdown]
# Reading Vocabulary

# %%
with open('vocabulary.json','r') as infile:
    vocabulary=json.load(infile)

# %%
with open('tags.json','r') as infile:
    tags=json.load(infile)

# %%
vocabulary,tags
# Out:
# (['abdomen',
#   'abdominal',
#   'abnormal',
#   'acidity',
#   'acute',
#   'alcohol',
#   'altered',
#   'anal',
#   'and',
#   'anus',
#   'anxiety',
#   'appetite',
#   'around',
#   'back',
#   'balance',
#   'behind',
#   'belly',
#   'blackhead',
#   'bladder',
#   'bleeding',
#   'blister',
#   'blood',
#   'bloody',
#   'blurred',
#   'body',
#   'bowel',
#   'breathlessness',
#   'brittle',
#   'bruising',
#   'burning',
#   'calf',
#   'chest',
#   'chill',
#   'cold',
#   'coma',
#   'concentration',
#   'congestion',
#   'constipation',
#   'consumption',
#   'contact',
#   'continuous',
#   'cough',
#   'cramp',
#   'crust',
#   'dark',
#   'dehydration',
#   'dent',
#   'depression',
#   'diarrhoea',
#   'discomfort',
#   'distention',
#   'distorted',
#   'disturbance',
#   'dizziness',
#   'drying',
#   'during',
#   'dusting',
#   'enlarged',
#   'eruption',
#   'excessive',
#   'extra',
#   'extremeties',
#   'eye',
#   'face',
#   'failure',
#   'family',
#   'fast',
#   'fatigue',
#   'feel',
#   'feets',
#   'fever',
#   'filled',
#   'fluid',
#   'from',
#   'gain',
#   'gas',
#   'hand',
#   'headache',
#   'heart',
#   'high',
#   'hip',
#   'history',
#   'hunger',
#   'in',
#   'increased',
#   'indigestion',
#   'inflammatory',
#   'injection',
#   'internal',
#   'irregular',
#   'irritability',
#   'irritation',
#   'itching',
#   'joint',
#   'knee',
#   'lack',
#   'leg',
#   'lethargy',
#   'level',
#   'like',
#   'limb',
#   'lip',
#   'liver',
#   'look',
#   'loss',
#   'lymph',
#   'malaise',
#   'marital',
#   'menstruation',
#   'micturition',
#   'mild',
#   'mood',
#   'movement',
#   'mucoid',
#   'muscle',
#   'nail',
#   'nausea',
#   'neck',
#   'nodal',
#   'node',
#   'nose',
#   'obesity',
#   'of',
#   'on',
#   'one',
#   'ooze',
#   'over',
#   'overload',
#   'pain',
#   'painful',
#   'palpitation',
#   'passage',
#   'patch',
#   'peeling',
#   'phlegm',
#   'pimple',
#   'polyuria',
#   'pressure',
#   'prominent',
#   'pu',
#   'puffy',
#   'rash',
#   'rate',
#   'receiving',
#   'red',
#   'redness',
#   'region',
#   'restlessness',
#   'runny',
#   'rusty',
#   'scurring',
#   'sensorium',
#   'shivering',
#   'side',
#   'silver',
#   'sinus',
#   'skin',
#   'slurred',
#   'small',
#   'smell',
#   'sneezing',
#   'sore',
#   'speech',
#   'spinning',
#   'spot',
#   'sputum',
#   'stiff',
#   'stiffness',
#   'stomach',
#   'stool',
#   'sugar',
#   'sunken',
#   'sweating',
#   'swelled',
#   'swelling',
#   'swing',
#   'swollen',
#   'the',
#   'throat',
#   'thyroid',
#   'tingling',
#   'tongue',
#   'toxic',
#   'transfusion',
#   'typhos',
#   'ulcer',
#   'unsteadiness',
#   'unsterile',
#   'urine',
#   'vein',
#   'vessel',
#   'vision',
#   'visual',
#   'vomiting',
#   'walking',
#   'wasting',
#   'watering',
#   'weakness',
#   'weight',
#   'yellow',
#   'yellowing',
#   'yellowish'],
#  ['(vertigo) Paroymsal  Positional Vertigo',
#   'AIDS',
#   'Acne',
#   'Alcoholic hepatitis',
#   'Allergy',
#   'Arthritis',
#   'Bronchial Asthma',
#   'Cervical spondylosis',
#   'Chicken pox',
#   'Chronic cholestasis',
#   'Common Cold',
#   'Dengue',
#   'Diabetes',
#   'Dimorphic hemmorhoids(piles)',
#   'Drug Reaction',
#   'Fungal infection',
#   'GERD',
#   'Gastroenteritis',
#   'Heart attack',
#   'Hepatitis B',
#   'Hepatitis C',
#   'Hepatitis D',
#   'Hepatitis E',
#   'Hypertension',
#   'Hyperthyroidism',
#   'Hypoglycemia',
#   'Hypothyroidism',
#   'Impetigo',
#   'Jaundice',
#   'Malaria',
#   'Migraine',
#   'Osteoarthristis',
#   'Paralysis (brain hemorrhage)',
#   'Peptic ulcer diseae',
#   'Pneumonia',
#   'Psoriasis',
#   'Tuberculosis',
#   'Typhoid',
#   'Urinary tract infection',
#   'Varicose veins',
#   'hepatitis A'])

# %% [markdown]
# One Hot Encoding input sentences

# %%
lemma_object= WordNetLemmatizer()

# %%
def bag_of_words(tokenized_pattern,vocabulary): #Accepts vocabulary which is the prepared Json file
    tokenized_pattern=[lemma_object.lemmatize(word) for word in tokenized_pattern ]
    bag= np.zeros(len(vocabulary),dtype=int)
    #One Hot Encoding
    for i, word in enumerate(vocabulary):
        if word in tokenized_pattern:
            bag[i]=1
    return bag

# %% [markdown]
# Read Classifier

# %%
f = open('MultiNaive.pickle', 'rb')
disease_detect_model = pickle.load(f)
f.close()

# %% [markdown]
# Chat!

# %%
def reply(message):
    words = nltk.word_tokenize(message)#Tokenize input sentence
    bag = bag_of_words(words,vocabulary) # One Hot encoding
    bag = np.reshape(bag,(-1,1)) # Reshaping
    bag = np.transpose(bag) # Transpose
    prediction=disease_detect_model.predict(bag) #Predicting the output
    label=tags[prediction[0]]
    for intent in intents['intents']:
        if label == intent['tag']:
          return intent["responses"][0]

# %%
sentence = 'vomiting dehydration diarrhoea sunken_eyes'
reply(sentence)
# Out:
# 'you have Gastroenteritis'
